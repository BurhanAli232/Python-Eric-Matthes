# %% [markdown]
# # Concatination of sring

# %%
string1=input('Enter your first name: ')
string2=input('Enter your last nmae: ')
print(string1 + ' ' + string2)
# Out:
# burhan ali

# %%
string1=string1.title()
full_name=string1+' '+string2
print(full_name.capitalize())
# Out:
# Burhan ali

# %%
full_name=full_name.upper()
print(full_name)
# Out:
# BURHAN ALI

# %%
full_name=full_name.lower()
print(full_name)
# Out:
# burhan ali

# %% [markdown]
# # Adding white space with tabs or newline

# %% [markdown]
# - whitespace refre to nonprinting character such as space,tab,end of line symbols

# %% [markdown]
# ### 1-Tab(\t)
# - when we use tab or \t mostly add 4 space so let's try

# %%
print(f'welcome {full_name} to the python world!')
print('Now we check the white space using\ttab or you can simple click tab key')
# Out:
# welcome burhan ali to the python world!
# Now we check the white space using	tab or you can simple click tab key

# %%
print('another sample with multiple\ttabs')
# Out:
# another sample with multiple	tabs

# %% [markdown]
# ### 2-newline (\n)
# - when we use \n the cursor go to new line

# %%
print('burhan\nali')
# Out:
# burhan
# ali

# %%
print('Language:\n\tPython\n\tC++\n\tJavaScript')
# Out:
# Language:
# 	Python
# 	C++
# 	JavaScript
