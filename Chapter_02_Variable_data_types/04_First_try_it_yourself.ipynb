# %% [markdown]
# # Problem
# - Try it yourself

# %% [markdown]
# ![Problem.png](attachment:Problem.png)

# %% [markdown]
# # 2_1_simple_message

# %%
# Store a message in variable and print that message
message="Hello Python world!" # Initial message
print(message) # Print the message
# Out:
# Hello Python world!

# %%
# Best Practice or more readable way
message="Hello Anmol" # Initial message
print(f'This is the message: {message}') # Print the message
# Out:
# This is the message: Hello Anmol

# %% [markdown]
# # 2_2_simple_messages

# %%
# Store a message in a variable and print that message then cgange the value of your variable to new message and print new message
message='Hello Python world!' # Initial message
print(message) # Print the initial message
message='Welcome to python programming!' # Update the message
print(message) # Print the updated message
# Out:
# Hello Python world!
# Welcome to python programming!

# %%
# Best Practice or more readable way
message='Hello Anmol' # Initial message
print(f'This is the first message: {message}') # Print the first message
message='Welcome Anmool to python programming!' # Update the message
print(f'This is the second message: {message}') # Print the updated message
# Out:
# This is the first message: Hello Anmol
# This is the second message: Welcome Anmool to python programming!
